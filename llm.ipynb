# %%
from langchain_community.document_loaders import PyPDFLoader

# Load a single PDF
loader = PyPDFLoader("resume.pdf")   # 👈 Replace with your PDF name
documents = loader.load()

print("Total pages loaded:", len(documents))
print("First page content:")
print(documents[0].page_content)
# Out:
# Total pages loaded: 2
# First page content:
# HARSHAL ZARIKAR
# harshalzarikar14@gmail.com
#
# +919284360901
#
# Pune, Maharashtra 431005
#
# linkedin.com/in/harshal-zarikar-182536209
#
# github.com/Harshalzarikar
#
# SUMMARY
# Results-driven AI/ML Engineer with strong proficiency in Python, Machine Learning, FastAPI, NLP, and Data Science. Experienced in
# developing LLM-based applications using Ollama, building scalable APIs, and implementing machine learning models through
# internships and hands-on projects. Skilled in data preprocessing, model training, evaluation, and deploying AI-driven solutions. Adept at
# problem-solving, delivering technical insights, and contributing effectively to collaborative development environments. Seeking to apply
# technical expertise and support innovation in a growth-oriented organization.
# EXPERIENCE
# Generative AI Intern
# Finsocial Digital System
# •Developed and deployed Generative AI and LLM-based applications using Ollama, improving NLP
# automation and text-generation workflows.
# •Built and optimized FastAPI services to serve AI/ML models with low latency and scalable API
# performance.
# •Created and containerized FastAPI applications using Docker, enabling reliable deployment environments
# and simplified CI/CD processes.
# •Designed and implemented web scraping and data extraction pipelines to support model training and
# business analytics.
# •Collaborated with the engineering team to integrate Generative AI solutions into production systems,
# focusing on performance tuning, scalability, and deployment readiness.
# Data Science Intern
# Feynnlab
# •Developed and evaluated machine learning models for multiple real-world use cases, including data
# preprocessing, feature engineering, and model optimization.
# •Performed exploratory data analysis (EDA) to identify trends, patterns, and actionable insights that
# supported data-driven decisions.
# •Improved model performance using hyperparameter tuning, cross-validation, and feature selection
# techniques.
# •Presented analytical findings and model outcomes to stakeholders, contributing to project strategy and
# solution refinement.
# •Collaborated with team members to build scalable, production-ready ML pipelines and ensure smooth
# integration with downstream applications.
# TECHNICAL SKILLS
# Languages — Java, Python, C, C++, MySQL, HTML/CSS, JavaScript ,SQLite, PostgreSQL,Redis ,Django REST Framework, RESTful API
# Development, Developer Tools — Git, Google Cloud Platform, VS Code, Visual Studio, PyCharm, Microsoft Office, Libraries — Pandas,
# NumPy, Matplotlib. TensorFlow, keras, Scikit-learn, OpenCV., Other — Machine Learning, RestAPI, data structure and Algorithm, Object
# Oriented Programming (OOPS), Reactjs., Soft Skills — Analytical thinking, Problem-solving, Time Management, Decision-making, Project
# management
# PROJECTS
# Hotel Booking System — Django, PostgreSQL (Deployed on Render)
# Designed and deployed a production-ready hotel booking web application featuring secure user
# authentication, room availability management, and automated booking workflows. Implemented a robust
# backend using Django with a PostgreSQL database to ensure high reliability and scalability. Integrated
# dynamic UI features using HTML, CSS, and JavaScript for a smooth booking  experience
# Tech Stack : Django, Python, PostgreSQL, HTML/CSS, JavaScript
# Live Demo: https://hotel-booking-system-6-83r2.onrender.com/booking/
# Emotion Detection from Images
# •Developed a Convolutional Neural Network (CNN) model to detect human emotions from facial images
# with high accuracy.
# •The model recognizes emotions like happiness, sadness, anger, and surprise through real-time analysis of
# user-uploaded images.
# •Tech Stack: Python, TensorFlow, OpenCV, Flask, CNN
# IPL Scorecard Prediction
# •Created a machine learning model to predict the final score of IPL cricket matches using historical match
# data.
# •Utilized regression techniques to analyze patterns and improve prediction accuracy.
# •Presented predictions and insights via a user-friendly interface for enhanced accessibility.
# •Tech Stack: Python, Pandas, Scikit-learn, Matplotlib.
# CERTIFICATIONS
# Machine Learning — (Simplilearn)
# EDUCATION
# B.Tech  Computer Science and Engineering (Artificial intelligence and Machine learning),
# 1 1 / 2 0 2 4  –  0 6 / 2 0 2 5
# r e m o t e
# 0 1 / 2 0 2 4  –  0 4 / 2 0 2 4
# r e m o t e
# 0 9 / 2 0 2 5  –  1 1 / 2 0 2 5
# 0 7 / 2 0 2 4  –  0 8 / 2 0 2 4
# 1 0 / 2 0 2 3  –  1 2 / 2 0 2 3
# 0 6 / 2 0 2 0  –  0 6 / 2 0 2 4
